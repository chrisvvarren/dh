# %%
import cv2
import matplotlib.pyplot as plt
from IPython.display import Image
from IPython.display import HTML

# %% [markdown]
# ## Let's use `matplotlib`'s `imread` function to bring the image into our Python environment
#
# * To do so, we pass the file's path to `plt.imread()`
# * Here let's do it with two images, and call them (arbitrarily) `nelson` (for Kadir Nelson, the artist) and `dec` (for Declaration of Independence)

# %%
nelson = plt.imread('nelson_leviathan_george_floyd.jpg')
dec = plt.imread('Declaration_Pg1of1_AC.jpg')

# %% [markdown]
# ### With `plt.figure()` we initialize a space for an image, which we can use to set parameters like `figsize`
# ### By passing the image to `plt.imshow()` we can display the image

# %%
plt.figure(figsize = (20,10))
plt.imshow(dec)

# %% [markdown]
# ## Now try it for yourself with `nelson`

# %%
Image('https://www.sketchpad.net/images/channelsrgb.gif')

# %% [markdown]
# ## To a computer, an image is just a set of instructions for what colors to display in each pixel
# * Those instructions usually come in the form of "channels"
# * Most images (including ours here) are composites of red, green, and blue channels, and they're represented as RGB values
# * So if we just ask Python to show us `dec`, let's see what we get:

# %%
dec

# %% [markdown]
# ## Turns out, it's basically just a list of lists or an `array`
# * Typing `.shape` will tell us how many rows and columns there are in the array (the last number is how many channels there are)

# %%
dec.shape

# %% [markdown]
# ## Once we realize that we're just dealing with rows and columns, we can tell `matplotlib` that we only care about certain rows or columns.  For example:

# %%
plt.figure(figsize = (20,10))
dec_top = dec[0:1000,:]
plt.imshow(dec_top)

# %% [markdown]
# ### Now, using that `dec_top` image you've just creaed, try to isolate just the word 'Congress'

# %%
plt.figure(figsize = (30,100))
plt.imshow(nelson)

# %%
a_man_was_lynched = nelson[2800:4000, 300:2000]
plt.figure(figsize = (10,20))
plt.imshow(a_man_was_lynched)

# %%
man = nelson[2200:3800, 3000:3600]
plt.figure(figsize = (10,20))
plt.imshow(nelson[2200:3800, 3000:3600])
plt.savefig('./man.png')

# %%
selma = nelson[3300:3800, 3000:3600]
plt.figure(figsize = (10,10))
plt.imshow(selma)

# %%
caption = "detail from Nelson's 'Say Their Names'"
plt.figure(figsize = (15,15))
ims = [a_man_was_lynched, man]
for i,j in enumerate(ims):
    ax = plt.subplot(2,2,i+1)
    plt.imshow(j)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel(caption)
plt.tight_layout()
plt.savefig('nelson_protest.jpg', transparent=True, bbox_inches='tight')

# %%
lev = plt.imread('BM_425069001.jpg')
lev_top = lev[0:800, :]
ims = [nelson, lev]
plt.figure(figsize = (30,100))
plt.imshow(lev)

# %%
fig = plt.figure(figsize = (30,30))
credits = ['Kadir Nelson, "Say Their Names" (2020)', "Abraham Bosse, frontispiece to Thomas Hobbes' Leviathan (1651), courtesy of The British Museum"]

for i,j in enumerate(ims):
    ax = plt.subplot(1,3,i+1)
    plt.imshow(j)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel(credits[i])

plt.tight_layout()
plt.savefig('nelson_lev.jpg', transparent=True, bbox_inches='tight')

# %%
plt.figure(figsize = (30,100))
plt.imshow(lev[0:800, :])

# %%
nelson.shape

# %%
lev.shape

# %%
lev_top = lev[0:800, :]
lev_top.shape

# %%
credits = ["closeup of Leviathan frontispiece, courtesy of The British Museum"]
plt.figure(figsize = (20,20))
#plt.imshow(lev_top[400:700,400:1200])
ax = plt.subplot(111)
plt.imshow(lev_top[360:700,400:1200])
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel(credits[0])
plt.savefig('lev_body.jpg', transparent=True, bbox_inches='tight')

# %%
plt.figure(figsize = (20,20))
ax = plt.subplot(1,2,i+1)
plt.imshow(lev_top[360:700,400:1200])
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel(credits[0])
plt.tight_layout()
plt.savefig('lev_headless_body.jpg', transparent=True, bbox_inches='tight')

# %%
plt.figure(figsize = (20,20))
im1 = lev_top[360:700,500:1100]
im2 = lev
ims = [lev_top,im1]
for i,j in enumerate(ims):
    ax = plt.subplot(1,2,i+1)
    plt.imshow(j)
    ax.set_xticks([])
    ax.set_yticks([])
plt.tight_layout()
plt.savefig('hobbes_upclose.jpg', transparent=True, bbox_inches='tight')

# %%
credits = ["detail of Leviathan frontispiece, courtesy of The British Museum", "detail of Nelson's 'Say Their Names'"]

lev_body = lev[100:700,400:1200]
nelson_body = nelson[500:4000, 300:]
bodies = [lev_body, nelson_body]
plt.figure(figsize = (20,20))
for i,j in enumerate(bodies):
    ax = plt.subplot(1,2,i+1)
    plt.imshow(j)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel(credits[i])
plt.tight_layout()
plt.savefig('body_comp.jpg', transparent=True, bbox_inches='tight')

# %%
plt.figure(figsize = (30,30))
ax = plt.subplot(111)
lev_top = plt.imshow(lev[30:800,100:-30])
ax.set_xticks([])
ax.set_yticks([])
plt.savefig('lev_full_top.jpg', transparent=True, bbox_inches='tight')

# %%
plt.figure(figsize = (10,10))
ax = plt.subplot(111)
lev_top = plt.imshow(lev[300:750,200:700])
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel(credits[0])
plt.savefig('lev_left_arm.jpg', transparent=True, bbox_inches='tight')

# %%
ornaments = plt.imread('cmu_ornaments_frontispiece.tif')
plt.figure(figsize = (20,20))
plt.imshow(ornaments)

# %%
plt.figure(figsize = (20,20))
ax = plt.subplot(211)
plt.imshow(ornaments[1000:2200,600:-50])
ax = plt.subplot(212)
plt.imshow(lev[200:750,:])
plt.tight_layout()

# %%
levs = ['lev_0357.tif', 'lev_0359.tif', 'lev_0363.tif', 'lev_0365.tif']
ims = [plt.imread(i) for i in levs]

plt.figure(figsize = (16,9))

for i,j in enumerate(ims):
    ax = plt.subplot(4,1,i+1)
    if i == 1:
        plt.imshow(j[300:800,:-300])
    else:
        plt.imshow(j[300:800,:-300])
    if i == 2:
        ax.patch.set_edgecolor('limegreen')  
        ax.patch.set_linewidth(15)
    if i < 2:
        ax.patch.set_edgecolor('red')  
        ax.patch.set_linewidth(15)
    if i == 3: 
        ax.patch.set_edgecolor('orange')  
        ax.patch.set_linewidth(15)
    ax.set_xticks([])
    ax.set_yticks([])
#plt.tight_layout()
#plt.savefig('lev_running_title.jpg', transparent=False, bbox_inches='tight')

# %% [markdown]
# ## Aligning Two Images

# %%
import numpy as np
ims = [cv2.imread(i) for i in levs]
ims = [j[300:900,:-300] for j in ims]

img1_color = ims[0]  # Image to be aligned. 
img2_color = ims[1]    # Reference image. 
  
# Convert to grayscale. 
img1 = cv2.cvtColor(img1_color, cv2.COLOR_BGR2GRAY) 
img2 = cv2.cvtColor(img2_color, cv2.COLOR_BGR2GRAY) 
height, width = img2.shape 
  
# Create ORB detector with 5000 features. 
orb_detector = cv2.ORB_create(5000) 
  
# Find keypoints and descriptors. 
# The first arg is the image, second arg is the mask 
#  (which is not reqiured in this case). 
kp1, d1 = orb_detector.detectAndCompute(img1, None) 
kp2, d2 = orb_detector.detectAndCompute(img2, None) 
  
# Match features between the two images. 
# We create a Brute Force matcher with  
# Hamming distance as measurement mode. 
matcher = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck = True) 
  
# Match the two sets of descriptors. 
matches = matcher.match(d1, d2) 
  
# Sort matches on the basis of their Hamming distance. 
matches.sort(key = lambda x: x.distance) 
  
# Take the top 90 % matches forward. 
matches = matches[:int(len(matches)*90)] 
no_of_matches = len(matches) 
  
# Define empty matrices of shape no_of_matches * 2. 
p1 = np.zeros((no_of_matches, 2)) 
p2 = np.zeros((no_of_matches, 2)) 
  
for i in range(len(matches)): 
    p1[i, :] = kp1[matches[i].queryIdx].pt 
    p2[i, :] = kp2[matches[i].trainIdx].pt 

# Find the homography matrix. 
homography, mask = cv2.findHomography(p1, p2, cv2.RANSAC) 
  
# Use this matrix to transform the 
# colored image wrt the reference image. 
transformed_img = cv2.warpPerspective(img1_color, 
                    homography, (width, height)) 
  
# Save the output. 
#cv2.imwrite('output.jpg', transformed_img) 
plt.figure(figsize = (20,20))
plt.imshow(cv2.cvtColor(img2_color + transformed_img, cv2.COLOR_BGR2RGB))

# %%
transformed_img*4

# %%
plt.imshow(cv2.cvtColor(test[300:800,:-300], cv2.COLOR_BGR2RGB))

# %%
ims = [cv2.imread(i) for i in levs]
ims = [j[300:800,:-300] for j in ims]

# %%
levs = ['lev_0357.tif', 'lev_0359.tif', 'lev_0363.tif', 'lev_0365.tif']
ims = [plt.imread(i) for i in levs]

# %%
for i,im in enumerate(ims):
    plt.imshow(im)
    plt.show()
    plt.savefig(str(i)+'.jpg', dpi=500)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-2de685abd960> in <module>
#       1 for i,im in enumerate(ims):
# ----> 2     plt.imshow(im)
#       3     plt.show()
#       4     plt.savefig(str(i)+'.jpg', dpi=500)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2681         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2682         resample=resample, url=url, **({"data": data} if data is not
# -> 2683         None else {}), **kwargs)
#    2684     sci(__ret)
#    2685     return __ret
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
# ...
