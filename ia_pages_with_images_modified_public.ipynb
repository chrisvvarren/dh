# %% [markdown]
# # Viewing Pages with Images from Internet Archive
# adapted from Stephen Krewson, “Extracting Illustrated Pages from Digital Libraries with Python,” Programming Historian, January 14, 2019, https://programminghistorian.org/en/lessons/extracting-illustrated-pages.
#
# - displays pages for Internet Archive books with pictures or illustrations, using ABBYY fine reader data from Internet Archive
# - the main differences from Krewson's lesson is that instead of dowloading pages from Internet Archive, this notebook calls out to IIIF URLS to (a.) preview the results of internet archive queries and (b.) displays IA-hosted IIIF results in tabs in the notebook itself via ```ipyplot```

# %% [markdown]
# ## Import Libraries and Enter Credentials

# %%
import requests
import ipyplot
from IPython.display import Image
from IPython.display import display, HTML
import gzip
import os
import sys
import xml.etree.ElementTree as ET
import internetarchive as ia

# Dnter IA credentials
ia_email = input("please enter IA account email")
ia_password = input("please enter IA account password")

# add these credentials to the API's configuration object
ia.configure(ia_email, ia_password)

## to use more of the browser window for display
display(HTML(data="""
<style> div#notebook-container { width: 95%; } div#menubar-container { width: 95%; } div#maintoolbar-container { width: 99%; } </style>

"""))

# %% [markdown]
# ## Define Functions

# %%
# define a function for downloading pictures from a given IA volume
def ia_picture_urls(item_id, out_dir=None, out_urls=False):
    """
    :param item_id: unique Internet Archive volume identifier
    :param out_dir: destination for images; if None, no download
    
    Note: if supplied, out_dir must be an existing directory and
    the caller must have write permissions in that directory
    
    :rtype list of pages with one or more blockType=Picture in Abbyy OCR data
    """

    print("[{}] Starting processing".format(item_id))
    
    # Use command-line client to see available metadata formats:
    # `ia metadata formats VOLUME_ID`
    
    # for this lesson, only the Abbyy file is needed
    returned_files = list(ia.get_files(item_id, formats=["Abbyy GZ"]))
    
    # make sure something got returned
    if len(returned_files) > 0:
        abbyy_file = returned_files[0].name
    else:
        print("[{}] Could not get Abbyy file".format(item_id))
        return None
    
    # download the abbyy file to CWD
    ia.download(item_id, formats=["Abbyy GZ"], ignore_existing=True, destdir=os.getcwd(), no_directory=True)
    
    # collect the pages with at least one picture block
    img_pages = []
    
    with gzip.open(abbyy_file) as fp:
        tree = ET.parse(fp)
        document = tree.getroot()
        for i, page in enumerate(document):
            for block in page:
                try:
                    if block.attrib['blockType'] == 'Picture':
                        img_pages.append(i)
                        break
                except KeyError:
                    continue
    
    # 0 is not a valid page for making GET requests to IA,
    #yet sometimes it's in the zipped Abbyy file
    img_pages = [page for page in img_pages if page > 0]
    
    # track for download progress report
    total_pages = len(img_pages)
    print("total pages", total_pages)

    # OCR files are huge, so just delete once we have pagelist
    os.remove(abbyy_file)
    

    urls = ["https://iiif.archivelab.org/iiif/{}${}/full/full/0/default.jpg".format(item_id, page) for page in img_pages]
    
    if out_urls == True:
        print(urls)
    else:
        pass
    
    # return list of URLs with 1+ picture blocks
    return urls

## Grid plotting function
def look(urls, labels=None):
    if len(urls) > 0:
        smaller = [x.replace('/full/full', '/full/,450') for x in urls]
        ipyplot.plot_images(smaller, max_images=None, labels=labels)
    else:
        print("No results for query")
        
def tabs(vol_ids):
    labels = []
    urls = []
    for item_id in vol_ids:
        try:
            bookwise_urls = ia_picture_urls(item_id)
            urls = urls + bookwise_urls
            labels = labels + [x.split('$')[0].split('.org/iiif/')[1] for x in bookwise_urls]
        except:
            pass
    return urls, labels

# %% [markdown]
# ## Query Internet Archive & Look at Thumbnails of Results
#
# - query guidelines at https://archive.org/advancedsearch.php

# %%
query = "milton date:[1650 TO 1655] mediatype:texts"
vol_ids = [result['identifier'] for result in ia.search_items(query)]
thumbs = ['https://archive.org/services/img/{}'.format(im) for im in vol_ids]
look(thumbs, labels=vol_ids)
print(vol_ids)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-a4Bah5HG5etNwUX5Hxib9m {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-a4Bah5HG5etNwUX5Hxib9m {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-a4Bah5HG5etNwUX5Hxib9m {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-a4Bah5HG5etNwUX5Hxib9m:checked ~ #ipyplot-html-viewer-textarea-a4Bah5HG5etNwUX5Hxib9m {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-a4Bah5HG5etNwUX5Hxib9m:checked + #ipyplot-html-viewer-label-a4Bah5HG5etNwUX5Hxib9m:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-a4Bah5HG5etNwUX5Hxib9m">
#         <label id="ipyplot-html-viewer-label-a4Bah5HG5etNwUX5Hxib9m" for="ipyplot-html-viewer-toggle-a4Bah5HG5etNwUX5Hxib9m">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-a4Bah5HG5etNwUX5Hxib9m" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-9tJre2Zy4TNuo97sKjwH7s {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-9tJre2Zy4TNuo97sKjwH7s {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-9tJre2Zy4TNuo97sKjwH7s">
#     <div class="ipyplot-placeholder-div-9tJre2Zy4TNuo97sKjwH7s">
#         <div id="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-85dmpHJUNtNKBVZtUq8qQv" class="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bub_gb_AuRss2enn0gC</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/bub_gb_AuRss2enn0gC</h4><img src="https://archive.org/services/img/bub_gb_AuRss2enn0gC"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-85dmpHJUNtNKBVZtUq8qQv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-9tJre2Zy4TNuo97sKjwH7s">
#         <div id="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-ehizrV9TjzC6KboRJuBpdq" class="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bub_gb_E7UdY_fFAq0C</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/bub_gb_E7UdY_fFAq0C</h4><img src="https://archive.org/services/img/bub_gb_E7UdY_fFAq0C"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-ehizrV9TjzC6KboRJuBpdq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-9tJre2Zy4TNuo97sKjwH7s">
#         <div id="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-9VYqiZcRLvxjQxJP5z2uXx" class="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bub_gb_dDFhAAAAcAAJ</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/bub_gb_dDFhAAAAcAAJ</h4><img src="https://archive.org/services/img/bub_gb_dDFhAAAAcAAJ"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-9VYqiZcRLvxjQxJP5z2uXx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-9tJre2Zy4TNuo97sKjwH7s">
#         <div id="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-8tdkGqUxbLvP58F8GKFA8m" class="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bub_gb_dPwJjf4BGU0C</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/bub_gb_dPwJjf4BGU0C</h4><img src="https://archive.org/services/img/bub_gb_dPwJjf4BGU0C"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-8tdkGqUxbLvP58F8GKFA8m">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-9tJre2Zy4TNuo97sKjwH7s">
#         <div id="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-htGKoMwFTe9E3a3Djd6VkL" class="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bub_gb_mHom52vCg4wC</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/bub_gb_mHom52vCg4wC</h4><img src="https://archive.org/services/img/bub_gb_mHom52vCg4wC"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-htGKoMwFTe9E3a3Djd6VkL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-9tJre2Zy4TNuo97sKjwH7s">
#         <div id="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-3jhH4LKF98sNRasCJGn9yP" class="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s">
#             <h4 styl
#         <style>
#         #ipyplot-imgs-container-div-9tJre2Zy4TNuo97sKjwH7s {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-9tJre2Zy4TNuo97sKjwH7s {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-9tJre2Zy4TNuo97sKjwH7s">
#     <div class="ipyplot-placeholder-div-9tJre2Zy4TNuo97sKjwH7s">
#         <div id="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-85dmpHJUNtNKBVZtUq8qQv" class="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bub_gb_AuRss2enn0gC</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/bub_gb_AuRss2enn0gC</h4><img src="https://archive.org/services/img/bub_gb_AuRss2enn0gC"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-85dmpHJUNtNKBVZtUq8qQv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-9tJre2Zy4TNuo97sKjwH7s">
#         <div id="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-ehizrV9TjzC6KboRJuBpdq" class="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bub_gb_E7UdY_fFAq0C</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/bub_gb_E7UdY_fFAq0C</h4><img src="https://archive.org/services/img/bub_gb_E7UdY_fFAq0C"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-ehizrV9TjzC6KboRJuBpdq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-9tJre2Zy4TNuo97sKjwH7s">
#         <div id="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-9VYqiZcRLvxjQxJP5z2uXx" class="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bub_gb_dDFhAAAAcAAJ</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/bub_gb_dDFhAAAAcAAJ</h4><img src="https://archive.org/services/img/bub_gb_dDFhAAAAcAAJ"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-9VYqiZcRLvxjQxJP5z2uXx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-9tJre2Zy4TNuo97sKjwH7s">
#         <div id="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-8tdkGqUxbLvP58F8GKFA8m" class="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bub_gb_dPwJjf4BGU0C</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/bub_gb_dPwJjf4BGU0C</h4><img src="https://archive.org/services/img/bub_gb_dPwJjf4BGU0C"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-8tdkGqUxbLvP58F8GKFA8m">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-9tJre2Zy4TNuo97sKjwH7s">
#         <div id="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-htGKoMwFTe9E3a3Djd6VkL" class="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bub_gb_mHom52vCg4wC</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/bub_gb_mHom52vCg4wC</h4><img src="https://archive.org/services/img/bub_gb_mHom52vCg4wC"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-htGKoMwFTe9E3a3Djd6VkL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-9tJre2Zy4TNuo97sKjwH7s">
#         <div id="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-3jhH4LKF98sNRasCJGn9yP" class="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bub_gb_qdUYvmyfLiEC</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/bub_gb_qdUYvmyfLiEC</h4><img src="https://archive.org/services/img/bub_gb_qdUYvmyfLiEC"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-3jhH4LKF98sNRasCJGn9yP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-9tJre2Zy4TNuo97sKjwH7s">
#         <div id="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-4gVbszR9eT8XrRHhmSbZeM" class="ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s">
#             <h4 style="font-size: 12px; word-wrap: break-word;">ned-kbn-all-00002983-001</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/ned-kbn-all-00002983-001</h4><img src="https://archive.org/services/img/ned-kbn-all-00002983-001"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9tJre2Zy4TNuo97sKjwH7s-4gVbszR9eT8XrRHhmSbZeM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# ['bub_gb_AuRss2enn0gC', 'bub_gb_E7UdY_fFAq0C', 'bub_gb_dDFhAAAAcAAJ', 'bub_gb_dPwJjf4BGU0C', 'bub_gb_mHom52vCg4wC', 'bub_gb_qdUYvmyfLiEC', 'ned-kbn-all-00002983-001']

# %%
# loop over our search results and call the function


urls, labels = tabs(vol_ids)
ipyplot.plot_class_tabs(urls, labels=labels)
# Out:
# [bub_gb_AuRss2enn0gC] Starting processing
# bub_gb_AuRss2enn0gC: d - success
# total pages 26
# [bub_gb_E7UdY_fFAq0C] Starting processing
# bub_gb_E7UdY_fFAq0C: d - success
# total pages 83
# [bub_gb_dDFhAAAAcAAJ] Starting processing
# bub_gb_dDFhAAAAcAAJ: d - success
# total pages 41
# [bub_gb_dPwJjf4BGU0C] Starting processing
# bub_gb_dPwJjf4BGU0C: d - success
# total pages 93
# [bub_gb_mHom52vCg4wC] Starting processing
# bub_gb_mHom52vCg4wC: d - success
# total pages 215
# [bub_gb_qdUYvmyfLiEC] Starting processing
# bub_gb_qdUYvmyfLiEC: d - success
# total pages 85
# [ned-kbn-all-00002983-001] Starting processing
# ned-kbn-all-00002983-001: d - success
# total pages 119
#     <style>
#         #ipyplot-html-viewer-toggle-53FEqP2bSEjTFW9wLGqXrs {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-53FEqP2bSEjTFW9wLGqXrs {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-53FEqP2bSEjTFW9wLGqXrs {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-53FEqP2bSEjTFW9wLGqXrs:checked ~ #ipyplot-html-viewer-textarea-53FEqP2bSEjTFW9wLGqXrs {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-53FEqP2bSEjTFW9wLGqXrs:checked + #ipyplot-html-viewer-label-53FEqP2bSEjTFW9wLGqXrs:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-53FEqP2bSEjTFW9wLGqXrs">
#         <label id="ipyplot-html-viewer-label-53FEqP2bSEjTFW9wLGqXrs" for="ipyplot-html-viewer-toggle-53FEqP2bSEjTFW9wLGqXrs">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-53FEqP2bSEjTFW9wLGqXrs" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb {
#                 display: none;
#             }
#             input.ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb + label.ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb:checked + label.ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb ~ .tab {
#                 display: none
#             }
#     #tabW9rvfXoc4cyeSThTLCHBih:checked ~ .tab.contentW9rvfXoc4cyeSThTLCHBih,#tabBPpLK9A9zSsb4mKdVdv5rM:checked ~ .tab.contentBPpLK9A9zSsb4mKdVdv5rM,#tabhXdgJMqdLDibRiqXHzGxN5:checked ~ .tab.contenthXdgJMqdLDibRiqXHzGxN5,#tabeNKEASwFC24TXCH3j7MxR3:checked ~ .tab.contenteNKEASwFC24TXCH3j7MxR3,#tab7K8mi6L5fRPhk3jCnGshNX:checked ~ .tab.content7K8mi6L5fRPhk3jCnGshNX,#tabiJgrcYmqh5oXGfQkXpPUDL:checked ~ .tab.contentiJgrcYmqh5oXGfQkXpPUDL,#tabK7xKNMZeZUKCLfbqazLULP:checked ~ .tab.contentK7xKNMZeZUKCLfbqazLULP{ display: block; }</style><input class="ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb" type="radio" name="tabs-X7YvTD2ipe6xifGwbfpZPb" id="tabW9rvfXoc4cyeSThTLCHBih" checked /><label class="ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb" for="tabW9rvfXoc4cyeSThTLCHBih">bub_gb_AuRss2enn0gC</label><input class="ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb" type="radio" name="tabs-X7YvTD2ipe6xifGwbfpZPb" id="tabBPpLK9A9zSsb4mKdVdv5rM"/><label class="ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb" for="tabBPpLK9A9zSsb4mKdVdv5rM">bub_gb_E7UdY_fFAq0C</label><input class="ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb" type="radio" name="tabs-X7YvTD2ipe6xifGwbfpZPb" id="tabhXdgJMqdLDibRiqXHzGxN5"/><label class="ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb" for="tabhXdgJMqdLDibRiqXHzGxN5">bub_gb_dDFhAAAAcAAJ</label><input class="ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb" type="radio" name="tabs-X7YvTD2ipe6xifGwbfpZPb" id="tabeNKEASwFC24TXCH3j7MxR3"/><label class="ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb" for="tabeNKEASwFC24TXCH3j7MxR3">bub_gb_dPwJjf4BGU0C</label><input class="ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb" type="radio" name="tabs-X7YvTD2ipe6xifGwbfpZPb" id="tab7K8mi6L5fRPhk3jCnGshNX"/><label class="ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb" for="tab7K8mi6L5fRPhk3jCnGshNX">bub_gb_mHom52vCg4wC</label><input class="ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb" type="radio" name="tabs-X7YvTD2ipe6xifGwbfpZPb" id="tabiJgrcYmqh5oXGfQkXpPUDL"/><label class="ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb" for="tabiJgrcYmqh5oXGfQkXpPUDL">bub_gb_qdUYvmyfLiEC</label><input class="ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb" type="radio" name="tabs-X7YvTD2ipe6xifGwbfpZPb" id="tabK7xKNMZeZUKCLfbqazLULP"/><label class="ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb" for="tabK7xKNMZeZUKCLfbqazLULP">ned-kbn-all-00002983-001</label><div class="tab contentW9rvfXoc4cyeSThTLCHBih">
#         <style>
#         #ipyplot-imgs-container-div-n2KUN4ah87XTidPWhYA4cB {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-n2KUN4ah87XTidPWhYA4cB {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-n2KUN4ah87XTidPWhYA4cB">
#     <div class="ipyplot-placeholder-div-n2KUN4ah87XTidPWhYA4cB">
#         <div id="ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB-Tfkd6JhWC9MZRNXjVGiRS7" class="ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://iiif.archivelab.org/iiif/bub_gb_AuRss2enn0gC$1/full/full/0/default.jpg</h4><img src="https://iiif.archivelab.org/iiif/bub_gb_AuRss2enn0gC$1/full/full/0/default.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB-Tfkd6JhWC9MZRNXjVGiRS7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-n2KUN4ah87XTidPWhYA4cB">
#         <div id="ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB-K3sp3ABVcbu3c2eeQs9K3P" class="ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
# <div>
#         <style>
#             input.ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb {
#                 display: none;
#             }
#             input.ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb + label.ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb:checked + label.ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb ~ .tab {
#                 display: none
#             }
#     #tabW9rvfXoc4cyeSThTLCHBih:checked ~ .tab.contentW9rvfXoc4cyeSThTLCHBih,#tabBPpLK9A9zSsb4mKdVdv5rM:checked ~ .tab.contentBPpLK9A9zSsb4mKdVdv5rM,#tabhXdgJMqdLDibRiqXHzGxN5:checked ~ .tab.contenthXdgJMqdLDibRiqXHzGxN5,#tabeNKEASwFC24TXCH3j7MxR3:checked ~ .tab.contenteNKEASwFC24TXCH3j7MxR3,#tab7K8mi6L5fRPhk3jCnGshNX:checked ~ .tab.content7K8mi6L5fRPhk3jCnGshNX,#tabiJgrcYmqh5oXGfQkXpPUDL:checked ~ .tab.contentiJgrcYmqh5oXGfQkXpPUDL,#tabK7xKNMZeZUKCLfbqazLULP:checked ~ .tab.contentK7xKNMZeZUKCLfbqazLULP{ display: block; }</style><input class="ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb" type="radio" name="tabs-X7YvTD2ipe6xifGwbfpZPb" id="tabW9rvfXoc4cyeSThTLCHBih" checked /><label class="ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb" for="tabW9rvfXoc4cyeSThTLCHBih">bub_gb_AuRss2enn0gC</label><input class="ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb" type="radio" name="tabs-X7YvTD2ipe6xifGwbfpZPb" id="tabBPpLK9A9zSsb4mKdVdv5rM"/><label class="ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb" for="tabBPpLK9A9zSsb4mKdVdv5rM">bub_gb_E7UdY_fFAq0C</label><input class="ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb" type="radio" name="tabs-X7YvTD2ipe6xifGwbfpZPb" id="tabhXdgJMqdLDibRiqXHzGxN5"/><label class="ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb" for="tabhXdgJMqdLDibRiqXHzGxN5">bub_gb_dDFhAAAAcAAJ</label><input class="ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb" type="radio" name="tabs-X7YvTD2ipe6xifGwbfpZPb" id="tabeNKEASwFC24TXCH3j7MxR3"/><label class="ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb" for="tabeNKEASwFC24TXCH3j7MxR3">bub_gb_dPwJjf4BGU0C</label><input class="ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb" type="radio" name="tabs-X7YvTD2ipe6xifGwbfpZPb" id="tab7K8mi6L5fRPhk3jCnGshNX"/><label class="ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb" for="tab7K8mi6L5fRPhk3jCnGshNX">bub_gb_mHom52vCg4wC</label><input class="ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb" type="radio" name="tabs-X7YvTD2ipe6xifGwbfpZPb" id="tabiJgrcYmqh5oXGfQkXpPUDL"/><label class="ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb" for="tabiJgrcYmqh5oXGfQkXpPUDL">bub_gb_qdUYvmyfLiEC</label><input class="ipyplot-tab-X7YvTD2ipe6xifGwbfpZPb" type="radio" name="tabs-X7YvTD2ipe6xifGwbfpZPb" id="tabK7xKNMZeZUKCLfbqazLULP"/><label class="ipyplot-tab-label-X7YvTD2ipe6xifGwbfpZPb" for="tabK7xKNMZeZUKCLfbqazLULP">ned-kbn-all-00002983-001</label><div class="tab contentW9rvfXoc4cyeSThTLCHBih">
#         <style>
#         #ipyplot-imgs-container-div-n2KUN4ah87XTidPWhYA4cB {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-n2KUN4ah87XTidPWhYA4cB {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-n2KUN4ah87XTidPWhYA4cB">
#     <div class="ipyplot-placeholder-div-n2KUN4ah87XTidPWhYA4cB">
#         <div id="ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB-Tfkd6JhWC9MZRNXjVGiRS7" class="ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://iiif.archivelab.org/iiif/bub_gb_AuRss2enn0gC$1/full/full/0/default.jpg</h4><img src="https://iiif.archivelab.org/iiif/bub_gb_AuRss2enn0gC$1/full/full/0/default.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB-Tfkd6JhWC9MZRNXjVGiRS7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-n2KUN4ah87XTidPWhYA4cB">
#         <div id="ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB-K3sp3ABVcbu3c2eeQs9K3P" class="ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://iiif.archivelab.org/iiif/bub_gb_AuRss2enn0gC$2/full/full/0/default.jpg</h4><img src="https://iiif.archivelab.org/iiif/bub_gb_AuRss2enn0gC$2/full/full/0/default.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB-K3sp3ABVcbu3c2eeQs9K3P">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-n2KUN4ah87XTidPWhYA4cB">
#         <div id="ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB-h53htAkc2BKvjEmZ22QboF" class="ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://iiif.archivelab.org/iiif/bub_gb_AuRss2enn0gC$3/full/full/0/default.jpg</h4><img src="https://iiif.archivelab.org/iiif/bub_gb_AuRss2enn0gC$3/full/full/0/default.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-n2KUN4ah87XTidPWhYA4cB-h53htAkc2BKvjEmZ22QboF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-n2KUN4ah87XTidPWhYA4cB">
#         <div id="ipyplot-content-div-n2KUN4ah87XTidPWhYA
