# %% [markdown]
# # Viewing Pages with Images from Internet Archive
# adapted from Stephen Krewson, “Extracting Illustrated Pages from Digital Libraries with Python,” Programming Historian, January 14, 2019, https://programminghistorian.org/en/lessons/extracting-illustrated-pages.
#
# - displays pages for Internet Archive books with picutes or illustrations, using ABBYY fine reader data from Internet Archvie
# - the main differences from Krewson's lesson is that instead of dowloading pages from Internet Archive, this notebook calls out to IIIF URLS to (a.) preview the results of internet archive quries and (b.) displays IA-hosted IIIF results in tabs in the notebook itself via ```ipyplot```

# %% [markdown]
# ## Import Libraries and Enter Credentials

# %%
import requests
import ipyplot
from IPython.display import Image
from IPython.display import display, HTML
import gzip
import os
import sys
import xml.etree.ElementTree as ET
import internetarchive as ia

# Dnter IA credentials
ia_email = input("please enter IA account email")
ia_password = input("please enter IA account password")

# add these credentials to the API's configuration object
ia.configure(ia_email, ia_password)

## to use more of the browser window for display
display(HTML(data="""
<style> div#notebook-container { width: 95%; } div#menubar-container { width: 95%; } div#maintoolbar-container { width: 99%; } </style>

"""))

# %% [markdown]
# ## Define Functions

# %%
# define a function for downloading pictures from a given IA volume
def ia_picture_urls(item_id, out_dir=None, out_urls=False):
    """
    :param item_id: unique Internet Archive volume identifier
    :param out_dir: destination for images; if None, no download
    
    Note: if supplied, out_dir must be an existing directory and
    the caller must have write permissions in that directory
    
    :rtype list of pages with one or more blockType=Picture in Abbyy OCR data
    """

    print("[{}] Starting processing".format(item_id))
    
    # Use command-line client to see available metadata formats:
    # `ia metadata formats VOLUME_ID`
    
    # for this lesson, only the Abbyy file is needed
    returned_files = list(ia.get_files(item_id, formats=["Abbyy GZ"]))
    
    # make sure something got returned
    if len(returned_files) > 0:
        abbyy_file = returned_files[0].name
    else:
        print("[{}] Could not get Abbyy file".format(item_id))
        return None
    
    # download the abbyy file to CWD
    ia.download(item_id, formats=["Abbyy GZ"], ignore_existing=True, destdir=os.getcwd(), no_directory=True)
    
    # collect the pages with at least one picture block
    img_pages = []
    
    with gzip.open(abbyy_file) as fp:
        tree = ET.parse(fp)
        document = tree.getroot()
        for i, page in enumerate(document):
            for block in page:
                try:
                    if block.attrib['blockType'] == 'Picture':
                        img_pages.append(i)
                        break
                except KeyError:
                    continue
    
    # 0 is not a valid page for making GET requests to IA,
    #yet sometimes it's in the zipped Abbyy file
    img_pages = [page for page in img_pages if page > 0]
    
    # track for download progress report
    total_pages = len(img_pages)
    print("total pages", total_pages)

    # OCR files are huge, so just delete once we have pagelist
    os.remove(abbyy_file)
    

    urls = ["https://iiif.archivelab.org/iiif/{}${}/full/full/0/default.jpg".format(item_id, page) for page in img_pages]
    
    if out_urls == True:
        print(urls)
    else:
        pass
    
    # return list of URLs with 1+ picture blocks
    return urls

## Grid plotting function
def look(urls, labels=None):
    if len(urls) > 0:
        smaller = [x.replace('/full/full', '/full/,450') for x in urls]
        ipyplot.plot_images(smaller, max_images=None, labels=labels)
    else:
        print("No results for query")
        
def tabs(vol_ids):
    labels = []
    urls = []
    for item_id in vol_ids:
        try:
            bookwise_urls = ia_picture_urls(item_id)
            urls = urls + bookwise_urls
            labels = labels + [x.split('$')[0].split('.org/iiif/')[1] for x in bookwise_urls]
        except:
            pass
    return urls, labels

# %% [markdown]
# ## Query Internet Archive & Look at Thumbnails of Results
#
# - query guidelines at https://archive.org/advancedsearch.php

# %%
query = "milton date:[1640 TO 1650] mediatype:texts"
vol_ids = [result['identifier'] for result in ia.search_items(query)]
thumbs = ['https://archive.org/services/img/{}'.format(im) for im in vol_ids]
look(thumbs, labels=vol_ids)
print(vol_ids)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-78Wy8HM8qzhnm9MmRgqsx9 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-78Wy8HM8qzhnm9MmRgqsx9 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-78Wy8HM8qzhnm9MmRgqsx9 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-78Wy8HM8qzhnm9MmRgqsx9:checked ~ #ipyplot-html-viewer-textarea-78Wy8HM8qzhnm9MmRgqsx9 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-78Wy8HM8qzhnm9MmRgqsx9:checked + #ipyplot-html-viewer-label-78Wy8HM8qzhnm9MmRgqsx9:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-78Wy8HM8qzhnm9MmRgqsx9">
#         <label id="ipyplot-html-viewer-label-78Wy8HM8qzhnm9MmRgqsx9" for="ipyplot-html-viewer-toggle-78Wy8HM8qzhnm9MmRgqsx9">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-78Wy8HM8qzhnm9MmRgqsx9" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-kh5RPtBqiqpyWcpm8tf3pY {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-kh5RPtBqiqpyWcpm8tf3pY {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-kh5RPtBqiqpyWcpm8tf3pY">
#     <div class="ipyplot-placeholder-div-kh5RPtBqiqpyWcpm8tf3pY">
#         <div id="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-fhzBPxrocMhMq6DaGtWhAu" class="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">doctrinediscipli00milt</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/doctrinediscipli00milt</h4><img src="https://archive.org/services/img/doctrinediscipli00milt"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-fhzBPxrocMhMq6DaGtWhAu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kh5RPtBqiqpyWcpm8tf3pY">
#         <div id="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-5nTvPrsuqJ9cZAbNMoD2yK" class="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">eikonoklastesina00milt</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/eikonoklastesina00milt</h4><img src="https://archive.org/services/img/eikonoklastesina00milt"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-5nTvPrsuqJ9cZAbNMoD2yK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kh5RPtBqiqpyWcpm8tf3pY">
#         <div id="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-2Xa5ZJmYwUj4yi53rpJG6S" class="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">miltonapologyforsmectymnuus1642yaleocr</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/miltonapologyforsmectymnuus1642yaleocr</h4><img src="https://archive.org/services/img/miltonapologyforsmectymnuus1642yaleocr"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-2Xa5ZJmYwUj4yi53rpJG6S">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kh5RPtBqiqpyWcpm8tf3pY">
#         <div id="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-j42iRnmmbEgUL9GLZGHYDP" class="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">miltonapologyforsmectymnuus1642yaleocr_202001</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/miltonapologyforsmectymnuus1642yaleocr_202001</h4><img src="https://archive.org/services/img/miltonapologyforsmectymnuus1642yaleocr_202001"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-j42iRnmmbEgUL9GLZGHYDP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kh5RPtBqiqpyWcpm8tf3pY">
#         <div id="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-oSteKB6yfudBGMv4egYbu3" class="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">miltonareopagitica1644</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/miltonareopagitica1644</h4><img src="https://archive.org/services/img/miltonareopagitica1644"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-oSteKB6yfudBGMv4egYbu3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kh5RPtBqiqpyWcpm8tf
#         <style>
#         #ipyplot-imgs-container-div-kh5RPtBqiqpyWcpm8tf3pY {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-kh5RPtBqiqpyWcpm8tf3pY {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-kh5RPtBqiqpyWcpm8tf3pY">
#     <div class="ipyplot-placeholder-div-kh5RPtBqiqpyWcpm8tf3pY">
#         <div id="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-fhzBPxrocMhMq6DaGtWhAu" class="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">doctrinediscipli00milt</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/doctrinediscipli00milt</h4><img src="https://archive.org/services/img/doctrinediscipli00milt"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-fhzBPxrocMhMq6DaGtWhAu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kh5RPtBqiqpyWcpm8tf3pY">
#         <div id="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-5nTvPrsuqJ9cZAbNMoD2yK" class="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">eikonoklastesina00milt</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/eikonoklastesina00milt</h4><img src="https://archive.org/services/img/eikonoklastesina00milt"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-5nTvPrsuqJ9cZAbNMoD2yK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kh5RPtBqiqpyWcpm8tf3pY">
#         <div id="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-2Xa5ZJmYwUj4yi53rpJG6S" class="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">miltonapologyforsmectymnuus1642yaleocr</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/miltonapologyforsmectymnuus1642yaleocr</h4><img src="https://archive.org/services/img/miltonapologyforsmectymnuus1642yaleocr"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-2Xa5ZJmYwUj4yi53rpJG6S">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kh5RPtBqiqpyWcpm8tf3pY">
#         <div id="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-j42iRnmmbEgUL9GLZGHYDP" class="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">miltonapologyforsmectymnuus1642yaleocr_202001</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/miltonapologyforsmectymnuus1642yaleocr_202001</h4><img src="https://archive.org/services/img/miltonapologyforsmectymnuus1642yaleocr_202001"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-j42iRnmmbEgUL9GLZGHYDP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kh5RPtBqiqpyWcpm8tf3pY">
#         <div id="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-oSteKB6yfudBGMv4egYbu3" class="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">miltonareopagitica1644</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/miltonareopagitica1644</h4><img src="https://archive.org/services/img/miltonareopagitica1644"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-oSteKB6yfudBGMv4egYbu3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kh5RPtBqiqpyWcpm8tf3pY">
#         <div id="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-HZArnnMRLQvdSx7MfV5mFr" class="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">poemsbothenglish00miltuoft</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/poemsbothenglish00miltuoft</h4><img src="https://archive.org/services/img/poemsbothenglish00miltuoft"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-HZArnnMRLQvdSx7MfV5mFr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kh5RPtBqiqpyWcpm8tf3pY">
#         <div id="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-GWxsLioTHuwvPRV5dC7U3A" class="ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">poemsofmrjohnmil00milt</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://archive.org/services/img/poemsofmrjohnmil00milt</h4><img src="https://archive.org/services/img/poemsofmrjohnmil00milt"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kh5RPtBqiqpyWcpm8tf3pY-GWxsLioTHuwvPRV5dC7U3A">
#                 <span class="ipyplot-im
# ['doctrinediscipli00milt', 'eikonoklastesina00milt', 'miltonapologyforsmectymnuus1642yaleocr', 'miltonapologyforsmectymnuus1642yaleocr_202001', 'miltonareopagitica1644', 'poemsbothenglish00miltuoft', 'poemsofmrjohnmil00milt', 'reasonofchurchgo00milt']

# %%
# loop over our search results and call the function


urls, labels = tabs(vol_ids)
ipyplot.plot_class_tabs(urls, labels=labels)
# Out:
# [doctrinediscipli00milt] Starting processing
# doctrinediscipli00milt: d - success
# total pages 4
# [eikonoklastesina00milt] Starting processing
# eikonoklastesina00milt: d - success
# total pages 18
# [miltonapologyforsmectymnuus1642yaleocr] Starting processing
# miltonapologyforsmectymnuus1642yaleocr: d - success
# total pages 92
# [miltonapologyforsmectymnuus1642yaleocr_202001] Starting processing
# miltonapologyforsmectymnuus1642yaleocr_202001: d - success
# total pages 92
# [miltonareopagitica1644] Starting processing
# miltonareopagitica1644: d - success
# total pages 2
# [poemsbothenglish00miltuoft] Starting processing
# poemsbothenglish00miltuoft: d - success
# total pages 11
# [poemsofmrjohnmil00milt] Starting processing
# poemsofmrjohnmil00milt: d - success
# total pages 49
# [reasonofchurchgo00milt] Starting processing
# reasonofchurchgo00milt: d - success
# total pages 20
#     <style>
#         #ipyplot-html-viewer-toggle-4BCsJbjEKnXXZawdQYGFcF {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-4BCsJbjEKnXXZawdQYGFcF {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-4BCsJbjEKnXXZawdQYGFcF {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-4BCsJbjEKnXXZawdQYGFcF:checked ~ #ipyplot-html-viewer-textarea-4BCsJbjEKnXXZawdQYGFcF {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-4BCsJbjEKnXXZawdQYGFcF:checked + #ipyplot-html-viewer-label-4BCsJbjEKnXXZawdQYGFcF:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-4BCsJbjEKnXXZawdQYGFcF">
#         <label id="ipyplot-html-viewer-label-4BCsJbjEKnXXZawdQYGFcF" for="ipyplot-html-viewer-toggle-4BCsJbjEKnXXZawdQYGFcF">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-4BCsJbjEKnXXZawdQYGFcF" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-kS4dQCiSpPXCk9TRz3B539 {
#                 display: none;
#             }
#             input.ipyplot-tab-kS4dQCiSpPXCk9TRz3B539 + label.ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539 {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-kS4dQCiSpPXCk9TRz3B539:checked + label.ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539 {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-kS4dQCiSpPXCk9TRz3B539 ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-kS4dQCiSpPXCk9TRz3B539 ~ .tab {
#                 display: none
#             }
#     #tabAeRrLqLQGeogMUQLeiJ2eh:checked ~ .tab.contentAeRrLqLQGeogMUQLeiJ2eh,#tabUknbzfdSpjUgJrXMpJFgLy:checked ~ .tab.contentUknbzfdSpjUgJrXMpJFgLy,#tabSgQVtEaEUXPc58sHEiMCrZ:checked ~ .tab.contentSgQVtEaEUXPc58sHEiMCrZ,#tabfoaXRotSY94ajDGnLgE59e:checked ~ .tab.contentfoaXRotSY94ajDGnLgE59e,#tabNW6zqB4v9KJFtL6avJ9XRN:checked ~ .tab.contentNW6zqB4v9KJFtL6avJ9XRN,#tabQkeJEo558MWizJcL2oufFX:checked ~ .tab.contentQkeJEo558MWizJcL2oufFX,#tabJSRC6NPfxxqE5vXAZWeDr6:checked ~ .tab.contentJSRC6NPfxxqE5vXAZWeDr6,#tabCrm7qF3C5ufJo7pQzZhMnA:checked ~ .tab.contentCrm7qF3C5ufJo7pQzZhMnA{ display: block; }</style><input class="ipyplot-tab-kS4dQCiSpPXCk9TRz3B539" type="radio" name="tabs-kS4dQCiSpPXCk9TRz3B539" id="tabAeRrLqLQGeogMUQLeiJ2eh" checked /><label class="ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539" for="tabAeRrLqLQGeogMUQLeiJ2eh">doctrinediscipli00milt</label><input class="ipyplot-tab-kS4dQCiSpPXCk9TRz3B539" type="radio" name="tabs-kS4dQCiSpPXCk9TRz3B539" id="tabUknbzfdSpjUgJrXMpJFgLy"/><label class="ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539" for="tabUknbzfdSpjUgJrXMpJFgLy">eikonoklastesina00milt</label><input class="ipyplot-tab-kS4dQCiSpPXCk9TRz3B539" type="radio" name="tabs-kS4dQCiSpPXCk9TRz3B539" id="tabSgQVtEaEUXPc58sHEiMCrZ"/><label class="ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539" for="tabSgQVtEaEUXPc58sHEiMCrZ">miltonapologyforsmectymnuus1642yaleocr</label><input class="ipyplot-tab-kS4dQCiSpPXCk9TRz3B539" type="radio" name="tabs-kS4dQCiSpPXCk9TRz3B539" id="tabfoaXRotSY94ajDGnLgE59e"/><label class="ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539" for="tabfoaXRotSY94ajDGnLgE59e">miltonapologyforsmectymnuus1642yaleocr_202001</label><input class="ipyplot-tab-kS4dQCiSpPXCk9TRz3B539" type="radio" name="tabs-kS4dQCiSpPXCk9TRz3B539" id="tabNW6zqB4v9KJFtL6avJ9XRN"/><label class="ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539" for="tabNW6zqB4v9KJFtL6avJ9XRN">miltonareopagitica1644</label><input class="ipyplot-tab-kS4dQCiSpPXCk9TRz3B539" type="radio" name="tabs-kS4dQCiSpPXCk9TRz3B539" id="tabQkeJEo558MWizJcL2oufFX"/><label class="ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539" for="tabQkeJEo558MWizJcL2oufFX">poemsbothenglish00miltuoft</label><input class="ipyplot-tab-kS4dQCiSpPXCk9TRz3B539" type="radio" name="tabs-kS4dQCiSpPXCk9TRz3B539" id="tabJSRC6NPfxxqE5vXAZWeDr6"/><label class="ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539" for="tabJSRC6NPfxxqE5vXAZWeDr6">poemsofmrjohnmil00milt</label><input class="ipyplot-tab-kS4dQCiSpPXCk9TRz3B539" type="radio" name="tabs-kS4dQCiSpPXCk9TRz3B539" id="tabCrm7qF3C5ufJo7pQzZhMnA"/><label class="ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539" for="tabCrm7qF3C5ufJo7pQzZhMnA">reasonofchurchgo00milt</label><div class="tab contentAeRrLqLQGeogMUQLeiJ2eh">
#         <style>
#         #ipyplot-imgs-container-div-5YSrziJ9dJdnkgsv8TucxF {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-5YSrziJ9dJdnkgsv8TucxF {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-5YSrziJ9dJdnkgsv8TucxF">
#     <div class="ipyplot-placeholder-div-5YSrziJ9dJdnkgsv8TucxF">
#         <div id="ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF-UPbwNBL9sCeLQtgrESjHVq" class="ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://iiif.archivelab.org/iiif/doctrinediscipli00milt$11/full/full/0/default.jpg</h4><img src="https://iiif.archivelab.org/iiif/doctrinediscipli00milt$11/full/full/0/default.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF-UPbwNBL9sCeLQtg
# <div>
#         <style>
#             input.ipyplot-tab-kS4dQCiSpPXCk9TRz3B539 {
#                 display: none;
#             }
#             input.ipyplot-tab-kS4dQCiSpPXCk9TRz3B539 + label.ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539 {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-kS4dQCiSpPXCk9TRz3B539:checked + label.ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539 {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-kS4dQCiSpPXCk9TRz3B539 ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-kS4dQCiSpPXCk9TRz3B539 ~ .tab {
#                 display: none
#             }
#     #tabAeRrLqLQGeogMUQLeiJ2eh:checked ~ .tab.contentAeRrLqLQGeogMUQLeiJ2eh,#tabUknbzfdSpjUgJrXMpJFgLy:checked ~ .tab.contentUknbzfdSpjUgJrXMpJFgLy,#tabSgQVtEaEUXPc58sHEiMCrZ:checked ~ .tab.contentSgQVtEaEUXPc58sHEiMCrZ,#tabfoaXRotSY94ajDGnLgE59e:checked ~ .tab.contentfoaXRotSY94ajDGnLgE59e,#tabNW6zqB4v9KJFtL6avJ9XRN:checked ~ .tab.contentNW6zqB4v9KJFtL6avJ9XRN,#tabQkeJEo558MWizJcL2oufFX:checked ~ .tab.contentQkeJEo558MWizJcL2oufFX,#tabJSRC6NPfxxqE5vXAZWeDr6:checked ~ .tab.contentJSRC6NPfxxqE5vXAZWeDr6,#tabCrm7qF3C5ufJo7pQzZhMnA:checked ~ .tab.contentCrm7qF3C5ufJo7pQzZhMnA{ display: block; }</style><input class="ipyplot-tab-kS4dQCiSpPXCk9TRz3B539" type="radio" name="tabs-kS4dQCiSpPXCk9TRz3B539" id="tabAeRrLqLQGeogMUQLeiJ2eh" checked /><label class="ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539" for="tabAeRrLqLQGeogMUQLeiJ2eh">doctrinediscipli00milt</label><input class="ipyplot-tab-kS4dQCiSpPXCk9TRz3B539" type="radio" name="tabs-kS4dQCiSpPXCk9TRz3B539" id="tabUknbzfdSpjUgJrXMpJFgLy"/><label class="ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539" for="tabUknbzfdSpjUgJrXMpJFgLy">eikonoklastesina00milt</label><input class="ipyplot-tab-kS4dQCiSpPXCk9TRz3B539" type="radio" name="tabs-kS4dQCiSpPXCk9TRz3B539" id="tabSgQVtEaEUXPc58sHEiMCrZ"/><label class="ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539" for="tabSgQVtEaEUXPc58sHEiMCrZ">miltonapologyforsmectymnuus1642yaleocr</label><input class="ipyplot-tab-kS4dQCiSpPXCk9TRz3B539" type="radio" name="tabs-kS4dQCiSpPXCk9TRz3B539" id="tabfoaXRotSY94ajDGnLgE59e"/><label class="ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539" for="tabfoaXRotSY94ajDGnLgE59e">miltonapologyforsmectymnuus1642yaleocr_202001</label><input class="ipyplot-tab-kS4dQCiSpPXCk9TRz3B539" type="radio" name="tabs-kS4dQCiSpPXCk9TRz3B539" id="tabNW6zqB4v9KJFtL6avJ9XRN"/><label class="ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539" for="tabNW6zqB4v9KJFtL6avJ9XRN">miltonareopagitica1644</label><input class="ipyplot-tab-kS4dQCiSpPXCk9TRz3B539" type="radio" name="tabs-kS4dQCiSpPXCk9TRz3B539" id="tabQkeJEo558MWizJcL2oufFX"/><label class="ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539" for="tabQkeJEo558MWizJcL2oufFX">poemsbothenglish00miltuoft</label><input class="ipyplot-tab-kS4dQCiSpPXCk9TRz3B539" type="radio" name="tabs-kS4dQCiSpPXCk9TRz3B539" id="tabJSRC6NPfxxqE5vXAZWeDr6"/><label class="ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539" for="tabJSRC6NPfxxqE5vXAZWeDr6">poemsofmrjohnmil00milt</label><input class="ipyplot-tab-kS4dQCiSpPXCk9TRz3B539" type="radio" name="tabs-kS4dQCiSpPXCk9TRz3B539" id="tabCrm7qF3C5ufJo7pQzZhMnA"/><label class="ipyplot-tab-label-kS4dQCiSpPXCk9TRz3B539" for="tabCrm7qF3C5ufJo7pQzZhMnA">reasonofchurchgo00milt</label><div class="tab contentAeRrLqLQGeogMUQLeiJ2eh">
#         <style>
#         #ipyplot-imgs-container-div-5YSrziJ9dJdnkgsv8TucxF {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-5YSrziJ9dJdnkgsv8TucxF {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-5YSrziJ9dJdnkgsv8TucxF">
#     <div class="ipyplot-placeholder-div-5YSrziJ9dJdnkgsv8TucxF">
#         <div id="ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF-UPbwNBL9sCeLQtgrESjHVq" class="ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://iiif.archivelab.org/iiif/doctrinediscipli00milt$11/full/full/0/default.jpg</h4><img src="https://iiif.archivelab.org/iiif/doctrinediscipli00milt$11/full/full/0/default.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF-UPbwNBL9sCeLQtgrESjHVq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5YSrziJ9dJdnkgsv8TucxF">
#         <div id="ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF-6QiSbUjE6XyhF8a9ijjGKT" class="ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://iiif.archivelab.org/iiif/doctrinediscipli00milt$127/full/full/0/default.jpg</h4><img src="https://iiif.archivelab.org/iiif/doctrinediscipli00milt$127/full/full/0/default.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF-6QiSbUjE6XyhF8a9ijjGKT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5YSrziJ9dJdnkgsv8TucxF">
#         <div id="ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF-cpgiC58sfck2FfTTW9hZWA" class="ipyplot-content-div-5YSrziJ9dJdnkgsv8TucxF">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://iiif.archivelab.org/iiif/doctrinediscipli00milt$128/full/full/0/default.jpg</h4><img src="https://iiif.archivelab.org/iiif/doctrinediscipli00milt$128/full/full/0/default.jpg
