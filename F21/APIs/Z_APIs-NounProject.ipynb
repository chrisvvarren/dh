# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import requests
import json
from requests_oauthlib import OAuth1
from IPython.display import Image
from IPython.core.display import HTML 
import getpass
api_key = getpass.getpass()

# %%
secret = getpass.getpass()
# Out:
# ········

# %%
auth = OAuth1(api_key, secret)

path = '.'

url = 'http://api.thenounproject.com/collections?offset=250'
r = requests.get(url,  auth=auth)
j = json.dumps(r.json())
results = json.loads(j)
for r in results['collections']:
    print(r['name'])
# Out:
# Essential Businessj
# Outline : Business And Finance Icon set
# Creative
# Outline : Business And Finance
# mind process
# Doctor icon
# Cute Girl Side Profile Character
# Girl's Side Profile Character
# Skills
# Outline : Business And Finance IconSet
# My Paprica Feelings
# Camping
# Mothers day
# Iphone
# Iphone made by Directors
# Love
# Ramadan And Eid Line
# Mahatma Gandhi
# mark symbol
# Communication and Media
# Internet Security
# musical devices
# Ui Interface
# Celtic Trinity Knot
# Aviation
# Winter
# Spring
# Download
# Summer
# Home Screen Apps
# Financial Analyst
# Simple UX/UI Icons - Bold
# Travel Icon Set
# Arrow UI
# Retro Music
# Education Icon Set
# Photography equipment in solid style
# Aiken : Outline
# Hospital and Medical
# Video Conference UI
# Online Shop UI
# Coffee Shop
# Yoga
# modern user interface
# Shipping and Warehouse
# Beauty and Care
# Lumber Mill Deforestation
# Nature
# Kitchen Utensils
# Beauty And Cosmetics

# %% [markdown]
# [docs here]('https://developer.oxforddictionaries.com/documentation/getting_started')

# %%
len(results)
# Out:
# 1

# %%
slug = 'scavenger_hunt_map'
url = 'http://api.thenounproject.com/icon/173374'
r = requests.get(url,  auth=auth)

j = json.dumps(r.json())
results = json.loads(j)
f = plt.figure()

ax = f.add_subplot(111)
im = Image(url=results['icon']['preview_url_84'])
im = requests.get(results['icon']['preview_url_84'], auth=auth).content
#im = requests.get(icon['icon_url'], auth=auth).content
fn = results['icon']['preview_url_84'].split('/')[-1]
#svg = icon['icon_url'].split('?Expires')[0].split('/')[-1]
with open(path+slug+'_'+fn, "wb") as png:
    png.write(im)
im2 = plt.imread(path+slug+'_'+fn)
ax.imshow(im2)
ax.set_xticks([])
ax.set_yticks([])
plt.show()

# %%
#slug = 'distance-education-outline-part-2'

slug = 'virus-pandemic'
offset='0'
url = 'http://api.thenounproject.com/collection/{0}/icons?offset={1}'.format(slug,offset)
r = requests.get(url,  auth=auth)

j = json.dumps(r.json())
results = json.loads(j)
for icon in results['icons']:
    f = plt.figure()
    previews.append(icon['preview_url_84'])
    ax = f.add_subplot(111)
    im = Image(url=icon['preview_url_84'])
    im = requests.get(icon['preview_url'], auth=auth).content
    #im = requests.get(icon['icon_url'], auth=auth).content
    fn = icon['preview_url_84'].split('/')[-1]
   # svg = icon['icon_url'].split('?Expires')[0].split('/')[-1]
    with open(path+slug+'_'+fn, "wb") as png:
        png.write(im)
    im2 = plt.imread(path+slug+'_'+fn)
    ax.imshow(im2)
    ax.set_xticks([])
    ax.set_yticks([])
    plt.show()

# %%
url_list = []
for icon in results['icons']:
    print(icon['icon_url'])
    url_list.append(icon['icon_url'])
# Out:
# https://static.thenounproject.com/noun-svg/4186.svg?Expires=1597726164&Signature=fEaK9W4myLlQNKiUMX6pUCOCzX5mbHqJGfN7mq4o3DhNGqp1EwKqDWpCBppHSUcxQpWXBSX-uOkQePh6KYNxvxVMd6NZyLFR5JO-uxvXZDZaMz6hEeTXa4dnlyjdzm4mILoNOvQDjqIKvW6Z4FFtowUHDuYN6DTkBLueuyY7P2Y_&Key-Pair-Id=APKAI5ZVHAXN65CHVU2Q
# https://static.thenounproject.com/noun-svg/2009204.svg?Expires=1597726164&Signature=TyAN8fbCSmtTNyMKhjNsWOh3T08z2KrYvtYoWnUpe1~lSWju-7x9Ejzo-~YmgFQB7dsSKHKwJsuAZK3U7W8lW8Rr~j0e5fmmzj0FKmwyy8hslbe8ucyQ8pESj1fhRuny-VLU7PsLeWG7UlMJQOW~OtaCNkWDv8FOsTl4eyyV-T0_&Key-Pair-Id=APKAI5ZVHAXN65CHVU2Q

# %%
r
# Out:
# <Response [404]>

# %%
Image(url=icon['preview_url_84'])
# Out:
# <img src="https://static.thenounproject.com/png/259924-84.png"/>

# %%
Image(url='https://static.thenounproject.com/png/1376378-84.png')
# Out:
# <img src="https://static.thenounproject.com/png/1376378-84.png"/>

# %%
icon['icon_url'].split('?Expires')[0].split('/')[-1]
# Out:
# '2009204.svg'

# %%
import urllib.request
for url in url_list:
    im = url.split('noun-svg/')[1].split('.')[0]
     

    urllib.request.urlretrieve(url, '../../'+im+'.svg')
    
    
    #image_content = requests.get(url).content
    #with open('../../'+im+'.png', "wb") as png:
     #   png.write(img.image)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-98-7cefc26b0b0c> in <module>
#       4
#       5
# ----> 6     urllib.request.urlretrieve(url, '../../'+im+'.svg')
#       7
#       8
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
# ...

# %%
icon['preview_url_84']
# Out:
# 'https://static.thenounproject.com/png/4448-84.png'

# %%
def grid_plot(imgs, figsz=None, save=True):
    if isinstance(imgs, list):
        is_flat = True
        X = len(imgs)
        M = N = int(np.ceil(np.sqrt(X)))
    elif len(imgs.shape)==4:
        M,N,H,W = imgs.shape
        is_flat = False
    else:
        is_flat = True
        X = imgs.shape[0]
        M = N = int(np.ceil(np.sqrt(X)))
    f = plt.figure(figsize=figsz if figsz else (10,5))
    for i in range(M):
        for j in range(N):
            num = i*N+j+1
            if is_flat and num>X:
                break
            img = imgs[num-1] if is_flat else imgs[i,j]
            ax = plt.subplot(M,N,num)
            ax.set_xticks([])
            ax.set_yticks([])
            ax.set_xlabel(num)
            ax.imshow(img)
# Out:
# 'https://static.thenounproject.com/png/1630974-84.png'

# %% [markdown]
# ### Check if there are 4 here as expected

# %%
len(results['icons'])
# Out:
# 50

# %%
print("code {}\n".format(r.status_code))
print("text \n" + r.text)
print("json \n" + json.dumps(r.json()))

# %%
num = '1376378'
url = 'http://api.thenounproject.com/icon/{0}?include_png_1200={1}'.format(num,num)
print(url)
k = requests.get(url,  auth=auth)
# Out:
# http://api.thenounproject.com/icon/1376378?include_png_1200=1376378

# %%
test = json.dumps(k.json())
t = json.loads(test)
#t['icon']['permalink']
t
# Out:
# {'icon': {'attribution': 'Big data by Eliricon from Noun Project',
#   'attribution_preview_url': 'https://static.thenounproject.com/attribution/1376378-600.png',
#   'collections': [{'author': {'location': 'FI',
#      'name': 'Eliricon',
#      'permalink': '/mordarius',
#      'username': 'mordarius'},
#     'author_id': '75079',
#     'date_created': '2017-10-28 21:15:02',
#     'date_updated': '2017-10-28 21:15:02',
#     'description': '',
#     'id': '41446',
#     'is_collaborative': '',
#     'is_featured': '0',
#     'is_published': '1',
#     'is_store_item': '0',
#     'name': 'Big Data',
#     'permalink': '/mordarius/collection/big-data',
#     'slug': 'big-data',
#     'sponsor': {},
#     'sponsor_campaign_link': '',
#     'sponsor_id': '',
#     'tags': [],
#     'template': '24'}],
#   'date_uploaded': '2017-10-28',
#   'id': '1376378',
#   'is_active': '1',
#   'is_explicit': '0',
#   'license_description': 'creative-commons-attribution',
#   'nounji_free': '0',
# ...

# %%
k.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
for url in url_list[0:1]:
    concat
    image_content = requests.get(url).content

# %%
requests.get(url).content
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?><Error><Code>AccessDenied</Code><Message>Access denied</Message></Error>'

# %%
url
# Out:
# 'https://static.thenounproject.com/noun-svg/4448.svg?Expires=1597720462&Signature=dSLmTejKzdX6UA5Ge28Zp9FWHy~8EGujzt8jUyX8Fee7ECW-4LesI5VuiqPX8XzZbX1U892dyqvM1fDn6pwWcyHRmptvBV-8SG3GsZjtmm6sU8RbMN2eq45i-6N9wpu66jZGUwQBaBoxYqy-DDdFDyoWnNs7uqut~imPkw9JMtg_&Key-Pair-Id=APKAI5ZVHAXN65CHVU2Q'

# %%
urllib.request.urlretrieve(url, '../../'+im+'.svg')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-100-1cfa4d952121> in <module>
# ----> 1 urllib.request.urlretrieve(url, '../../'+im+'.svg')
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
# ...

# %%
image_content = requests.get(url).content

# %%
path+slug+'_'+fn
# Out:
# '/Users/user/Box/Teaching (CMU)/iconsresearch-and-analysis-glyph-00003_3159908-84.png'
